# %%
import tensorflow as tf
from tensorflow import keras

# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='sgd',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=10)

test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# Epoch 1/10
# 1875/1875 [==============================] - 6s 2ms/step - loss: 163.4467 - accuracy: 0.1295
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 2.2337 - accuracy: 0.1350
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 2.2214 - accuracy: 0.1425
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 2.1941 - accuracy: 0.1494
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 2.1743 - accuracy: 0.1583
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 2.1704 - accuracy: 0.1585
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 2.2134 - accuracy: 0.1469
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 2.2141 - accuracy: 0.1425
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 2.2645 - accuracy: 0.1187
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 2.2847 - accuracy: 0.1087
# 313/313 - 1s - loss: 2.2615 - accuracy: 0.1174 - 666ms/epoch - 2ms/step
#
# Test accuracy: 0.11739999800920486

# %%
import tensorflow as tf
from tensorflow import keras

# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

train_images = train_images/255
test_images  = test_images/255

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='sgd',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=10)

test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7484 - accuracy: 0.7589
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5102 - accuracy: 0.8274
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4655 - accuracy: 0.8407
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4394 - accuracy: 0.8473
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4219 - accuracy: 0.8547
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4088 - accuracy: 0.8592
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3971 - accuracy: 0.8615
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3879 - accuracy: 0.8657
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3803 - accuracy: 0.8674
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3716 - accuracy: 0.8702
# 313/313 - 1s - loss: 0.4060 - accuracy: 0.8553 - 628ms/epoch - 2ms/step
#
# Test accuracy: 0.8553000092506409

# %%
import tensorflow as tf
from tensorflow import keras

# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.fit(train_images, train_labels, epochs=10)

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 3.3157 - accuracy: 0.6679
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.7784 - accuracy: 0.7128
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6759 - accuracy: 0.7345
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6484 - accuracy: 0.7436
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6357 - accuracy: 0.7475
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6098 - accuracy: 0.7576
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5954 - accuracy: 0.7688
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5923 - accuracy: 0.7710
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5802 - accuracy: 0.7774
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5713 - accuracy: 0.7786
# 313/313 - 1s - loss: 0.6535 - accuracy: 0.7679 - 568ms/epoch - 2ms/step
#
# Test accuracy: 0.7678999900817871

# %%
import tensorflow as tf
from tensorflow import keras

# Data Preparation
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

train_images = train_images / 255
test_images  = test_images / 255

# model
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
model.fit(train_images, train_labels, epochs=10)

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4992 - accuracy: 0.8256
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3767 - accuracy: 0.8638
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3382 - accuracy: 0.8765
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3144 - accuracy: 0.8844
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2953 - accuracy: 0.8905
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2798 - accuracy: 0.8965
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2677 - accuracy: 0.9004
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2556 - accuracy: 0.9049
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2460 - accuracy: 0.9079
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2353 - accuracy: 0.9126
# 313/313 - 1s - loss: 0.3345 - accuracy: 0.8822 - 613ms/epoch - 2ms/step
#
# Test accuracy: 0.8822000026702881
